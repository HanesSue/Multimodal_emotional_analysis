# %%
import pandas as pd

# %%
a = pd.read_csv("../data/ch-sims2s/ch-simsv2s/meta.csv")

# %%
a = a[a['mode'] == 'test']

# %%
a
# Out:
#         video_id clip_id                               text  label  label_T  \
# 2     video_0001    0003                我不想嫁入什么豪门，我们不就是豪门吗？   -1.0     -0.8
# 5     video_0001    0006                 够了，每次都是这一套，我不想再听了。   -1.0     -1.0
# 8     video_0001    0009                说到演讲啊，我不禁想起了我在我的母校。    0.4      0.4
# 16    video_0001    0017             到干妈的公司来做CEO啊，对对对，年薪一个亿    1.0      1.0
# 26    video_0001    0027              但是您现在可以卖身救集团，干还是不干是吧？    0.0     -0.8
# ...          ...     ...                                ...    ...      ...
# 4398      test15   00016                 很多都是表面上，实质性的东西都没有。   -0.4     -0.4
# 4399      test15   00017                  在俄罗斯没哟内卷，因为大家都很佛。    0.2      0.2
# 4400      test15   00018  就内卷很严重，我明白你自己心理很不舒服，但是你没办法改变游戏规则。   -0.4     -0.4
# 4401      test15   00019             那你就要适应游戏规则，不要觉得这个事情不对。   -0.2     -0.2
# 4402      test15   00020          这个事情是不对，这个事情是浪费时间，但是不要抱怨。   -0.4     -0.4
#
#       label_A  label_V annotation  mode
# ...
